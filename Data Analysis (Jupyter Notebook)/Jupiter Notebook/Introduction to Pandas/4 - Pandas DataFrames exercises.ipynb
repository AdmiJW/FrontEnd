# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# # Pandas DataFrame exercises

# %%
# Import the numpy package under the name np
import numpy as np

# Import the pandas package under the name pd
import pandas as pd

# Import the matplotlib package under the name plt
import matplotlib.pyplot as plt
# %matplotlib inline

# Print the pandas version and the configuration
print(pd.__version__)
# Out:
# 1.1.2

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame creation

# %% [markdown]
# ### Create an empty pandas DataFrame

# %%
df = pd.DataFrame( data=[None], 
                   index=[None],
                    columns=[None] )

print( df )
# Out:
#       NaN
# NaN  None

# %%
pd.DataFrame(data=[None],
             index=[None],
             columns=[None])

# %% [markdown]
# <img width=400 src="https://cdn.dribbble.com/users/4678/screenshots/1986600/avengers.png"></img>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a `marvel_df` pandas DataFrame with the given marvel data

# %%
marvel_data = [
    ['Spider-Man', 'male', 1962],
    ['Captain America', 'male', 1941],
    ['Wolverine', 'male', 1974],
    ['Iron Man', 'male', 1963],
    ['Thor', 'male', 1963],
    ['Thing', 'male', 1961],
    ['Mister Fantastic', 'male', 1961],
    ['Hulk', 'male', 1962],
    ['Beast', 'male', 1963],
    ['Invisible Woman', 'female', 1961],
    ['Storm', 'female', 1975],
    ['Namor', 'male', 1939],
    ['Hawkeye', 'male', 1964],
    ['Daredevil', 'male', 1964],
    ['Doctor Strange', 'male', 1963],
    ['Hank Pym', 'male', 1962],
    ['Scarlet Witch', 'female', 1964],
    ['Wasp', 'female', 1963],
    ['Black Widow', 'female', 1964],
    ['Vision', 'male', 1968]
]

# %%
df = pd.DataFrame( data = marvel_data,
                    columns = ['Name', 'Gender', 'Year'] )

df
# Out:
#                 Name  Gender  Year
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
marvel_df = pd.DataFrame(data=marvel_data)

marvel_df
# Out:
#                    0       1     2
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add column names to the `marvel_df`

# %%
df = pd.DataFrame( data = marvel_data )

column_name =["Name", "Gender", "Year"]
df.columns = column_name

# df = pd.DataFrame( data = marvel_data, columns=['Name', 'Gender', 'Year'] )

df
# Out:
#                 Name  Gender  Year
# 0         Spider-Man    male  1962
# 1    Captain America    male  1941
# 2          Wolverine    male  1974
# 3           Iron Man    male  1963
# 4               Thor    male  1963
# 5              Thing    male  1961
# 6   Mister Fantastic    male  1961
# 7               Hulk    male  1962
# 8              Beast    male  1963
# 9    Invisible Woman  female  1961
# 10             Storm  female  1975
# 11             Namor    male  1939
# 12           Hawkeye    male  1964
# 13         Daredevil    male  1964
# 14    Doctor Strange    male  1963
# 15          Hank Pym    male  1962
# 16     Scarlet Witch  female  1964
# 17              Wasp  female  1963
# 18       Black Widow  female  1964
# 19            Vision    male  1968

# %%
col_names = ['name', 'sex', 'first_appearance']

marvel_df.columns = col_names
marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add index names to the `marvel_df` (use the character name as index)

# %%
df = pd.DataFrame( data = marvel_data, columns = ['Name', 'Sex', 'First_Appearance'] )

df.index = df['Name']

df
# Out:
#                               Name     Sex  First_Appearance
# Name
# Spider-Man              Spider-Man    male              1962
# Captain America    Captain America    male              1941
# Wolverine                Wolverine    male              1974
# Iron Man                  Iron Man    male              1963
# Thor                          Thor    male              1963
# Thing                        Thing    male              1961
# Mister Fantastic  Mister Fantastic    male              1961
# Hulk                          Hulk    male              1962
# Beast                        Beast    male              1963
# Invisible Woman    Invisible Woman  female              1961
# Storm                        Storm  female              1975
# Namor                        Namor    male              1939
# Hawkeye                    Hawkeye    male              1964
# Daredevil                Daredevil    male              1964
# ...

# %%
marvel_df.index = marvel_df['name']
marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop the name column as it's now the index

# %%
df = pd.DataFrame( data = marvel_data,
                columns = ['Name', 'Sex', 'First Appearance'] )

df.index = df['Name']


df.drop(columns= 'Name' )

# df.drop(['Name'], axis=1)
# Out:
#                      Sex  First Appearance
# Name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Namor               male              1939
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Hank Pym            male              1962
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
#marvel_df = marvel_df.drop(columns=['name'])
marvel_df = marvel_df.drop(['name'], axis=1)
marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Drop 'Namor' and 'Hank Pym' rows

# %%
df = pd.DataFrame( data = marvel_data, columns=['Name', 'Sex', 'First Appearance'] )

df.index = df['Name']
df.drop( columns='Name', inplace=True)

df.drop( ['Namor', 'Hank Pym'] )

# df.drop( ['Namor', 'Hank Pym'], axis=0 )

# 0 is row
# 1 is column
# Out:
#                      Sex  First Appearance
# Name
# Spider-Man          male              1962
# Captain America     male              1941
# Wolverine           male              1974
# Iron Man            male              1963
# Thor                male              1963
# Thing               male              1961
# Mister Fantastic    male              1961
# Hulk                male              1962
# Beast               male              1963
# Invisible Woman   female              1961
# Storm             female              1975
# Hawkeye             male              1964
# Daredevil           male              1964
# Doctor Strange      male              1963
# Scarlet Witch     female              1964
# Wasp              female              1963
# Black Widow       female              1964
# Vision              male              1968

# %%
marvel_df = marvel_df.drop(['Namor', 'Hank Pym'], axis=0)
marvel_df

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame selection, slicing and indexation

# %% [markdown]
# ### Show the first 5 elements on `marvel_df`

# %%
df = pd.DataFrame( data = marvel_data, columns=['Name','Sex','Year'] )

df.index = df['Name']
df.drop('Name', axis=1, inplace=True)

# df.head()

# df.loc["Spider-Man": "Thor"]
df.iloc[0: 5]
df.iloc[0:5, :]
# Out:
#                   Sex  Year
# Name
# Spider-Man       male  1962
# Captain America  male  1941
# Wolverine        male  1974
# Iron Man         male  1963
# Thor             male  1963

# %%
#marvel_df.loc[['Spider-Man', 'Captain America', 'Wolverine', 'Iron Man', 'Thor'], :] # bad!
#marvel_df.loc['Spider-Man': 'Thor', :]
#marvel_df.iloc[0:5, :]
#marvel_df.iloc[0:5,]
marvel_df.iloc[:5,]
#marvel_df.head()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the last 5 elements on `marvel_df`

# %%
df = pd.DataFrame( data = marvel_data, columns=['Name', 'Sex', 'Year'] )

df.index = df["Name"]
df.drop( columns='Name', inplace=True )

df.tail()
df.iloc[-5: ]
df.loc["Hank Pym": "Vision"]
df.iloc[-5: , :]
# Out:
#                         Name     Sex  Year
# Name
# Hank Pym            Hank Pym    male  1962
# Scarlet Witch  Scarlet Witch  female  1964
# Wasp                    Wasp  female  1963
# Black Widow      Black Widow  female  1964
# Vision                Vision    male  1968

# %%
#marvel_df.loc[['Hank Pym', 'Scarlet Witch', 'Wasp', 'Black Widow', 'Vision'], :] # bad!
#marvel_df.loc['Hank Pym':'Vision', :]
marvel_df.iloc[-5:,]
#marvel_df.tail()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show just the sex of the first 5 elements on `marvel_df`

# %%
df = pd.DataFrame( data = marvel_data, columns=['Name', 'Sex', 'Year'] )

df.index = df['Name']
df.drop( 'Name', axis=1, inplace=True )

df.head()['Sex']      # head() returns a dataframe. Then using [] we select that column

df.iloc[0: 5, 0]      # If using iloc, it must all be number indices
df.iloc[0: 5]['Sex'].to_frame()     # Alternative is process one by one. That way we can use names. 
                                    # Remember to_frame() to show in data frame form
    
df.loc['Spider-Man':'Thor', 'Sex']
# Out:
# Name
# Spider-Man         male
# Captain America    male
# Wolverine          male
# Iron Man           male
# Thor               male
# Name: Sex, dtype: object

# %%
#marvel_df.iloc[:5,]['sex'].to_frame()
marvel_df.iloc[:5,].sex.to_frame()
#marvel_df.head().sex.to_frame()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first_appearance of all middle elements on `marvel_df`

# %%
df = pd.DataFrame( data = marvel_data, columns=['Name', 'Sex', 'Year'] )

df.index = df['Name']
df.drop (columns='Name', inplace=True)

df.iloc[1:-1]['Year'].to_frame()
# Out:
#                   Year
# Name
# Captain America   1941
# Wolverine         1974
# Iron Man          1963
# Thor              1963
# Thing             1961
# Mister Fantastic  1961
# Hulk              1962
# Beast             1963
# Invisible Woman   1961
# Storm             1975
# Namor             1939
# Hawkeye           1964
# Daredevil         1964
# Doctor Strange    1963
# Hank Pym          1962
# Scarlet Witch     1964
# Wasp              1963
# Black Widow       1964

# %%
marvel_df.iloc[1:-1,].first_appearance.to_frame()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Show the first and last elements on `marvel_df`

# %%
df.iloc[ [0, -1] ]
# Out:
#              Sex  Year
# Name
# Spider-Man  male  1962
# Vision      male  1968

# %%
#marvel_df.iloc[[0, -1],][['sex', 'first_appearance']]
marvel_df.iloc[[0, -1],]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame manipulation and operations

# %% [markdown]
# ### Modify the `first_appearance` of 'Vision' to year 1964

# %%
df.loc['Vision', 'Year'] = 1964

df.loc['Vision']
# Out:
# Sex     male
# Year    1964
# Name: Vision, dtype: object

# %%
marvel_df.loc['Vision', 'first_appearance'] = 1964

marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add a new column to `marvel_df` called 'years_since' with the years since `first_appearance`

# %%
df['Years Since'] = 2020 - df['Year']

df
# Out:
#                      Sex  Year  Years Since
# Name
# Spider-Man          male  1962           58
# Captain America     male  1941           79
# Wolverine           male  1974           46
# Iron Man            male  1963           57
# Thor                male  1963           57
# Thing               male  1961           59
# Mister Fantastic    male  1961           59
# Hulk                male  1962           58
# Beast               male  1963           57
# Invisible Woman   female  1961           59
# Storm             female  1975           45
# Namor               male  1939           81
# Hawkeye             male  1964           56
# Daredevil           male  1964           56
# Doctor Strange      male  1963           57
# Hank Pym            male  1962           58
# Scarlet Witch     female  1964           56
# Wasp              female  1963           57
# Black Widow       female  1964           56
# Vision              male  1964           56

# %%
marvel_df['years_since'] = 2018 - marvel_df['first_appearance']

marvel_df

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame boolean arrays (also called masks)

# %% [markdown]
# ### Given the `marvel_df` pandas DataFrame, make a mask showing the female characters

# %%
df['Sex'] == 'female'
# Out:
# Name
# Spider-Man          False
# Captain America     False
# Wolverine           False
# Iron Man            False
# Thor                False
# Thing               False
# Mister Fantastic    False
# Hulk                False
# Beast               False
# Invisible Woman      True
# Storm                True
# Namor               False
# Hawkeye             False
# Daredevil           False
# Doctor Strange      False
# Hank Pym            False
# Scarlet Witch        True
# Wasp                 True
# Black Widow          True
# Vision              False
# Name: Sex, dtype: bool

# %%
mask = marvel_df['sex'] == 'female'

mask

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the male characters

# %%
df.loc[ df['Sex'] == 'male' ]
# Out:
#                    Sex  Year  Years Since
# Name
# Spider-Man        male  1962           58
# Captain America   male  1941           79
# Wolverine         male  1974           46
# Iron Man          male  1963           57
# Thor              male  1963           57
# Thing             male  1961           59
# Mister Fantastic  male  1961           59
# Hulk              male  1962           58
# Beast             male  1963           57
# Namor             male  1939           81
# Hawkeye           male  1964           56
# Daredevil         male  1964           56
# Doctor Strange    male  1963           57
# Hank Pym          male  1962           58
# Vision            male  1964           56

# %%
mask = marvel_df['sex'] == 'male'

marvel_df[mask]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with `first_appearance` after 1970

# %%
df.loc[ df['Year'] > 1970 ]
# Out:
#               Sex  Year  Years Since
# Name
# Wolverine    male  1974           46
# Storm      female  1975           45

# %%
mask = marvel_df['first_appearance'] > 1970

marvel_df[mask]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-b596d9b1ff4a> in <module>
# ----> 1 mask = marvel_df['first_appearance'] > 1970
#       2
#       3 marvel_df[mask]
#
# c:\users\acer\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2900             if self.columns.nlevels > 1:
#    2901                 return self._getitem_multilevel(key)
# -> 2902             indexer = self.columns.get_loc(key)
#    2903             if is_integer(indexer):
#    2904                 indexer = [indexer]
#
# c:\users\acer\appdata\local\programs\python\python38-32\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     356                 except ValueError as err:
#     357                     raise KeyError(key) from err
# --> 358             raise KeyError(key)
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the female characters with `first_appearance` after 1970

# %%
df.loc[ (df['Sex'] == 'female') & (df['Year'] > 1970) ]
# Out:
#           Sex  Year  Years Since
# Name
# Storm  female  1975           45

# %%
mask = (marvel_df['sex'] == 'female') & (marvel_df['first_appearance'] > 1970)

marvel_df[mask]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame summary statistics

# %% [markdown]
# ### Show basic statistics of `marvel_df`

# %%
df.describe()
# Out:
#               Year  Years Since
# count    20.000000    20.000000
# mean   1961.650000    58.350000
# std       8.298859     8.298859
# min    1939.000000    45.000000
# 25%    1961.750000    56.000000
# 50%    1963.000000    57.000000
# 75%    1964.000000    58.250000
# max    1975.000000    81.000000

# %%
marvel_df.describe()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the mean value of `first_appearance`

# %%
df['Year'].mean()
# Out:
# 1961.65

# %%
#np.mean(marvel_df.first_appearance)
marvel_df.first_appearance.mean()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, show the min value of `first_appearance`

# %%
df['Year'].min()
# Out:
# 1939

# %%
#np.min(marvel_df.first_appearance)
marvel_df.first_appearance.min()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Given the `marvel_df` pandas DataFrame, get the characters with the min value of `first_appearance`

# %%
df.loc[ df['Year'] == df['Year'].min() ]
# Out:
#         Sex  Year  Years Since
# Name
# Namor  male  1939           81

# %%
mask = marvel_df['first_appearance'] == marvel_df.first_appearance.min()
marvel_df[mask]

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## DataFrame basic plottings

# %% [markdown]
# ### Reset index names of `marvel_df`

# %%
# df = df.reset_index()    # Will eject the index into a new column, and create default indexing
# Out:
#                 Name     Sex  Year  Years Since
# 0         Spider-Man    male  1962           58
# 1    Captain America    male  1941           79
# 2          Wolverine    male  1974           46
# 3           Iron Man    male  1963           57
# 4               Thor    male  1963           57
# 5              Thing    male  1961           59
# 6   Mister Fantastic    male  1961           59
# 7               Hulk    male  1962           58
# 8              Beast    male  1963           57
# 9    Invisible Woman  female  1961           59
# 10             Storm  female  1975           45
# 11             Namor    male  1939           81
# 12           Hawkeye    male  1964           56
# 13         Daredevil    male  1964           56
# 14    Doctor Strange    male  1963           57
# 15          Hank Pym    male  1962           58
# 16     Scarlet Witch  female  1964           56
# 17              Wasp  female  1963           57
# 18       Black Widow  female  1964           56
# ...

# %%
marvel_df = marvel_df.reset_index()

marvel_df

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot the values of `first_appearance`

# %%
df['Year'].plot()
# Out:
# <AxesSubplot:>

# %%
#plt.plot(marvel_df.index, marvel_df.first_appearance)
marvel_df.first_appearance.plot()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Plot a histogram (plot.hist) with values of `first_appearance`

# %%
plt.hist( df['Year'] )
# Out:
# (array([ 2.,  0.,  0.,  0.,  0.,  0., 16.,  0.,  0.,  2.]),
#  array([1939. , 1942.6, 1946.2, 1949.8, 1953.4, 1957. , 1960.6, 1964.2,
#         1967.8, 1971.4, 1975. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(marvel_df.first_appearance)

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
